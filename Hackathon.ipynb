# %%
vs = cv2.VideoCapture("test.mp4")

frames = [];
for i in range(1,4000):
    (grabbed, tmp) = vs.read()
    frames.append(tmp)

# %%
from imutils.object_detection import non_max_suppression
import numpy as np
import pytesseract
import argparse
import cv2
import imutils
import matplotlib.pyplot as plt

# %%
plt.imshow(frames[3800])

# %%
pytesseract.image_to_data
# Out:
# <function pytesseract.pytesseract.image_to_data(image, lang=None, config='', nice=0, output_type='string', timeout=0, pandas_config=None)>

# %%
cv2.imwrite("tmp2.jpg",frames[3800])
# Out:
# True

# %%
image = frames[2200]

# %%
plt.imshow(image[325:375,:,:])

# %%
pytesseract.image_to_string(image[325:375,:,:])
# Out:
# 'ea) yA Be) jt.\n\n \n\nsd\nEa'

# %%
tmp = image[325:375,:,:]

# %%
tmp_Mask = tmp*(tmp > 200);

# %%
tmp_Mask.shape
# Out:
# (50, 1280, 3)

# %%
# !python opencv-text-recognition\opencv-text-recognition\text_recognition.py --east opencv-text-recognition\opencv-text-recognition\frozen_east_text_detection.pb --image tmp.jpg --width 1280 --height 704 --padding 1
# Out:
# 704 1280
# [INFO] loading EAST text detector...
# [((681, 242, 1077, 318), ''), ((210, 321, 446, 417), '15:00 g'), ((384, 322, 548, 418), ''), ((878, 323, 978, 411), ''), ((935, 324, 1119, 408), 'tr Es\nBALL ON 35'), ((822, 324, 974, 408), 'a Tt it\nIST AND 10'), ((999, 325, 1119, 409), 'ett\nALL ON 35'), ((102, 326, 226, 406), '——\nST OTR'), ((1037, 327, 1137, 407), ''), ((63, 328, 183, 404), 'en\n_ 1STOTR'), ((790, 328, 914, 404), 'hha\n1ST AND 1'), ((1193, 329, 1280, 381), ''), ((1189, 343, 1280, 395), ''), ((168, 409, 320, 473), ''), ((544, 412, 640, 464), ''), ((940, 462, 1128, 534), ''), ((250, 470, 378, 558), ''), ((587, 520, 835, 620), '')]
#
#
# 15:00 g
#
#
#
#
#
# tr Es
# BALL ON 35
#
# a Tt it
# IST AND 10
#
# ett
# ALL ON 35
#
# ——
# ST OTR
#
#
#
# en
# _ 1STOTR
#
# hha
# 1ST AND 1

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-100f62972f2f> in <module>
# ----> 1 results
#
# NameError: name 'results' is not defined

# %%
plt.imshow(frames[2400])

# %%
tmp = frames[2401];

# %%
plt.imshow(tmp)

# %%
im = tmp
imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(imgray, 50, 255, 0)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
fig = cv2.drawContours(im, contours, -1, (0,255,0), 3)

# %%
plt.imshow(thresh)

# %%
kernel = np.ones((10,10),np.uint8)

# %%
plt.imshow(erosion)

# %%
erosion = cv2.dilate(dilation,kernel,iterations = 1)

# %%
dilation = cv2.erode(thresh,kernel,iterations = 1)

# %%
contours, hierarchy = cv2.findContours(erosion, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
fig = cv2.drawContours(im, contours, -1, (255,0,0), 3)

# %%
plt.imshow(fig)

# %%
plt.imshow(tmp)
